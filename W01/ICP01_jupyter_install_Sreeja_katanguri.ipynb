# %% [markdown]
# # ICP01 jupyter install
#
# ## Sreeja Katanguri

# %% [markdown]
# ![WIN_20230213_20_36_41_Pro.jpg](attachment:WIN_20230213_20_36_41_Pro.jpg)
#
# Hello professor I am a enrolled student of the BAIS program for fall @2022 , my name is Sreeja Katunguri. I come from computer science background and have 1 year professional experience in accenture company as an application developer associate

# %%
print(" hello world")
# Out:
#  hello world
